# %%
array = [1,2,3,4,5,6,6,7,8,45,34]
print(array[2])
# Out:
# 3

# %%
print("Hellofg")
# Out:
# Hellofg

# %%
for i in range(10):
    print("Hello")
# Out:
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
# Hello
